# %%
#This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'dbf315b1-dfe9-4e6d-b28f-3a7fc789aa13',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2023-06-03T14:00:50.379Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 2067, 'name': 'n0ay8kcp12', 'symbol': 'pdzimm8zm3n', 'slug': 'ufv7mdzxrd', 'cmc_rank': 5265, 'num_market_pairs': 3332, 'circulating_supply': 9051, 'total_supply': 4845, 'max_supply': 4115, 'infinite_supply': None, 'last_updated': '2023-06-03T14:00:50.378Z', 'date_added': '2023-06-03T14:00:50.378Z', 'tags': ['qreqdjpzfw', '2g52sk4cnyp', 'o6vzekmc07', '1wjw55wu31g', 'cdowvitoxqw', 'kku59bvwhfs', '7m1zlaoxb5u', 'enw2zr1czos', 'ugd3hp1a5id', '2mk0xxj9anj'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.8386918439240774, 'volume_24h': 6634, 'volume_change_24h': 0.12612847944056504, 'percent_change_1h': 0.12205941541286003, 'percent_change_24h': 0.43367294243138965, 'percent_change_7d': 0.34147514743503216, 'market_cap': 0.8125849852410105, 'market_cap_dominance': 2702, 'fully_diluted_market_cap': 0.5894907730434285, 'last_updated': '2023-06-03T14:00:50.378Z'}}}, {'id': 793, 'name': 'x16ql8o0p8', 'symbol': 'u87iaor4jy', 'slug': 'rbv0c4fg9te', 'cmc_rank': 203, 'num_market_pairs': 4558, 'circulating_supply': 5730, 'total_supply': 7946, 'max_supply': 5536, 'infinite_supply': None, 'last_updated': '2023-06-03T14:00:50.379Z', 'date_added': '2023-06-03T14:00:50.379Z', 'tags': ['i1m7x32ky18', 's1es8q9k5o', 'u37cnxvhc7q', '61mmrah0igq', '8uox6y93pnd', 'gwdzs7hb23p', '4iwy0ngq9q2', '9n4r19c6xc5', 'uwftmt8w0c', 'c82gf1ios1m'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.7861018499485712, 'volume_24h': 5516, 'volume_change_24h': 0.27037179526844946, 'percent_change_1h': 0.014714455118846281, 'percent_change_24h': 0.04642835868046147, 'percent_change_7d': 0.2529319864239279, 'market_cap': 0.2914357193389032, 'market_cap_dominance': 8194, 'fully_diluted_market_cap': 0.6183901997255299, 'last_updated': '2023-06-03T14:00:50.379Z'}}}, {'id': 5866, 'name': '6yvu64rckh6', 'symbol': '4jv1ff1ro5f', 'slug': 'laj8kj5uwl', 'cmc_rank': 6114, 'num_market_pairs': 6247, 'circulating_supply': 999, 'total_supply': 3955, 'max_supply': 1307, 'infinite_supply': None, 'last_updated': '2023-06-03T14:00:50.379Z', 'date_added': '2023-06-03T14:00:50.379Z', 'tags': ['wwowu10g8n', 'wd7j1yxl23j', '0okxc68fd48c', 'r5q1zsychr', 'sk971i6hzb', '02n1o17amh3x', 'hh3xqaxq3m', 'ekcqomxon1', '9eiypc2rs98', 'm6dy64islxj'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.1246084871462032, 'volume_24h': 5772, 'volume_change_24h': 0.25525829823202195, 'percent_change_1h': 0.2100219611851426, 'percent_change_24h': 0.5102407885797076, 'percent_change_7d': 0.7382853079411953, 'market_cap': 0.35704474382544626, 'market_cap_dominance': 1553, 'fully_diluted_market_cap': 0.9570551560500193, 'last_updated': '2023-06-03T14:00:50.379Z'}}}, {'id': 5188, 'name': 'tc4scap5y8n', 'symbol': '6h5qwtfh2x', 'slug': '9366zgwq2th', 'cmc_rank': 2629, 'num_market_pairs': 8276, 'circulating_supply': 7841, 'total_supply': 9806, 'max_supply': 4879, 'infinite_supply': None, 'last_updated': '2023-06-03T14:00:50.379Z', 'date_added': '2023-06-03T14:00:50.379Z', 'tags': ['oc5jxlddyy9', '9qhxg64slzu', 'j25zocajlj9', 'w0pakato3ps', 'qgo4ihx4y1p', 'm6a37xy1g', 's24c3nh7syk', 'nrh5nwpvbvp', 'pggxsuz8qok', 'i24i89huke'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.6379030449917109, 'volume_24h': 9753, 'volume_change_24h': 0.800646374952215, 'percent_change_1h': 0.914455160204438, 'percent_change_24h': 0.24244786472912883, 'percent_change_7d': 0.5829893801318811, 'market_cap': 0.6821004926947996, 'market_cap_dominance': 2727, 'fully_diluted_market_cap': 0.67913750118473, 'last_updated': '2023-06-03T14:00:50.379Z'}}}, {'id': 7748, 'name': 'arj226a57e', 'symbol': ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd


pd.set_option('display.max_rows', None)

# %%
pd.json_normalize(data['data'])
# Out:
#      id         name       symbol         slug  cmc_rank  num_market_pairs  \
# 0  2067   n0ay8kcp12  pdzimm8zm3n   ufv7mdzxrd      5265              3332
# 1   793   x16ql8o0p8   u87iaor4jy  rbv0c4fg9te       203              4558
# 2  5866  6yvu64rckh6  4jv1ff1ro5f   laj8kj5uwl      6114              6247
# 3  5188  tc4scap5y8n   6h5qwtfh2x  9366zgwq2th      2629              8276
# 4  7748   arj226a57e  jia1qp7jrul   ozsl5brg4y       834              4963
# 5  8824  7f51ic1dflk   jf40safwdx   k2g5v14zsj      8847              6690
# 6  2577  dqpx76h3aaw  non2u3hj3dc  dsuhl82dbqo      4376              5410
# 7  9569  bvh8qt0bdbk  cicb9sbnwmi  1qfgge7lyow      7292              8196
# 8  9946  bp1rc17m5bi   scac9e7j6m  7xymbpw6v3h       437              9675
# 9  7148  41hdlt0m7ms  t1ph0ow2alo  a68kv0ldumv      2802              9579
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# 0                9051          4845        4115            None  ...
# 1                5730          7946        5536            None  ...
# 2                 999          3955        1307            None  ...
# 3                7841          9806        4879            None  ...
# 4                3836          6876        7368            None  ...
# 5                6191          3967        2028            None  ...
# 6                4403          5201        2622            None  ...
# 7                3037          7079        1175            None  ...
# 8                2475          8725        4222            None  ...
# 9                5512          2604        5881            None  ...
#
#   quote.USD.price quote.USD.volume_24h quote.USD.volume_change_24h  \
# 0        0.838692                 6634                    0.126128
# 1        0.786102                 5516                    0.270372
# 2        0.124608                 5772                    0.255258
# 3        0.637903                 9753                    0.800646
# 4        0.403243                 5979                    0.455039
# 5        0.503444                 7932                    0.712737
# 6        0.749657                  551                    0.205430
# 7        0.617099                 8620                    0.590357
# 8        0.803414                 4430                    0.848499
# 9        0.623396                 3018                    0.826664
#
#   quote.USD.percent_change_1h quote.USD.percent_change_24h  \
# 0                    0.122059                     0.433673
# 1                    0.014714                     0.046428
# 2                    0.210022                     0.510241
# 3                    0.914455                     0.242448
# 4                    0.770802                     0.878519
# 5                    0.656258                     0.701939
# 6                    0.678626                     0.633443
# 7                    0.793373                     0.310436
# 8                    0.605327                     0.065805
# 9                    0.952174                     0.368186
#
#   quote.USD.percent_change_7d  quote.USD.market_cap  \
# 0                    0.341475              0.812585
# 1                    0.252932              0.291436
# 2                    0.738285              0.357045
# 3                    0.582989              0.682100
# 4                    0.684617              0.831294
# 5                    0.462021              0.463620
# 6                    0.202911              0.006705
# 7                    0.141704              0.212786
# 8                    0.584131              0.657836
# 9                    0.046002              0.425667
#
#    quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                            2702                            0.589491
# 1                            8194                            0.618390
# 2                            1553                            0.957055
# 3                            2727                            0.679138
# 4                            4660                            0.082538
# 5                            4838                            0.503680
# 6                            6378                            0.312977
# 7                            3444                            0.711103
# 8                            7053                            0.717279
# 9                            4242                            0.045347
#
#      quote.USD.last_updated
# 0  2023-06-03T14:00:50.378Z
# 1  2023-06-03T14:00:50.379Z
# 2  2023-06-03T14:00:50.379Z
# 3  2023-06-03T14:00:50.379Z
# 4  2023-06-03T14:00:50.379Z
# 5  2023-06-03T14:00:50.379Z
# 6  2023-06-03T14:00:50.379Z
# 7  2023-06-03T14:00:50.379Z
# 8  2023-06-03T14:00:50.379Z
# 9  2023-06-03T14:00:50.379Z
#
# [10 rows x 26 columns]
